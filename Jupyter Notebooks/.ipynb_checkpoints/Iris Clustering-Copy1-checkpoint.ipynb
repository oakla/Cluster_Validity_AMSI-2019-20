# %% [markdown]
# # Clustering the Iris Dataset

# %% [markdown]
# ### Libraries

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn.datasets import load_iris
from sklearn.preprocessing import scale

from sklearn.cluster import DBSCAN
import numpy as np
import matplotlib.pyplot as plt
import Toolbox.plotting_functions as plt_tools
import Toolbox.clustering_tools as clstr_tools

from sklearn import metrics

# %% [markdown]
# ### Data

# %%
X, y = load_iris(return_X_y=True)
X_scaled = scale(X)
n_samples, n_features = X.shape

# %% [markdown]
# ## Visualizing The Data

# %% [markdown]
# ### PCA

# %%
plt_tools.visualize_iris_ground_truth_3d()

# %%
plt_tools.visualize_iris_ground_truth_2d()

# %% [markdown]
# ## KMeans

# %% [markdown]
# ### Parameter Estimation
#
# Lets try finding the best value of k by comparing silhouette scores. We will also compare what happens with and without scaling here

# %%
k_with_highest_score, k_labels_dict = clstr_tools.benchmark_kmeans(X, [2,3,4,5,6,7,8,9,10])

print("According to silhouette scores, {0} is the optimal number of clusters".format(k_with_highest_score))
# Out:
# n_samples 150, 	 n_features 4
# Using the following methods for intial centroid placement: ['k-means++']
# __________________________________________________________________________________
# init/k-values	2       3       4       5       6       7       8       9       10
# k-means++	0.681	0.553	0.498	0.489	0.366	0.354	0.357	0.326	0.316
#
# According to silhouette scores, 2 is the optimal number of clusters

# %%
k_with_highest_score, k_labels_dict = clstr_tools.benchmark_kmeans(X_scaled, [2,3,4,5,6,7,8,9,10])

print("According to silhouette scores, {0} is the optimal number of clusters".format(k_with_highest_score))
# Out:
# n_samples 150, 	 n_features 4
# Using the following methods for intial centroid placement: ['k-means++']
# __________________________________________________________________________________
# init/k-values	2       3       4       5       6       7       8       9       10
# k-means++	0.582	0.460	0.388	0.346	0.323	0.335	0.333	0.337	0.349
#
# According to silhouette scores, 2 is the optimal number of clusters

# %% [raw]
# For some reason, 2 seems to be the best score in both cases.

# %% [markdown]
# ### Visualize the clusters
# Lets look at the ideal clusters as suggested by the silhouette score vs the true number

# %% [markdown]
# ### Iris 2 clusters

# %%
plt_tools.visualize_clusters(X, k_labels_dict[2], dims=2)
plt_tools.visualize_iris_ground_truth_2d()

# %% [markdown]
# ### Iris 3 Clusters

# %%
plt_tools.visualize_clusters(X, k_labels_dict[3], dims=2)
plt_tools.visualize_iris_ground_truth_2d()

# %% [markdown]
# #### KMeans conclusion
#
# The correct numnber of clusters is 3, but the silhouette score suggests otherwise. This is likely the result of the clusters in the Iris data set not being well-separated.

# %% [markdown]
# ## DBSCAN

# %% [markdown]
# ## Choosing eps and min_pts

# %% [markdown]
# ### min_pts
# Some researches suggest min_pts should be set to 4, but usually only for 2D data. Others say to use $min\_pts = 2 \times data\_dimensionality$. We'll try both and then compare the results
#
# ### eps
# eps can be found by measuring the distance of all points to their $j^{th}$ nearest neighbour. J is normally selected to be equal to $min\_pts - 1$
#
# ## k-distance plot

# %%
min_pts = 4
plt_tools.get_k_distance_plot(X_scaled, min_pts-1)

# %% [markdown]
# Let's go with $eps = 0.6$

# %%
eps = 0.6
db = DBSCAN(eps=eps, min_samples=min_pts).fit(X_scaled)
DBSCAN_estimated_labels_1 = db.labels_
n_clusters_ = len(set(DBSCAN_estimated_labels_1 )) - (1 if -1 in DBSCAN_estimated_labels_1  else 0)
n_noise_ = list(DBSCAN_estimated_labels_1 ).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
# Out:
# Estimated number of clusters: 3
# Estimated number of noise points: 19

# %% [markdown]
# That sounds alright. Let's see what this looks like
# ###  DBSCAN Cluster Visualization

# %%
plt_tools.visualize_clusters(X, DBSCAN_estimated_labels_1 , dims=2)
plt_tools.visualize_iris_ground_truth_2d()

# %%
plt_tools.visualize_clusters(X, DBSCAN_estimated_labels_1 , dims=2)
plt_tools.visualize_iris_ground_truth_2d()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-6b888cc7644d> in <module>
# ----> 1 plt_tools.visualize_clusters(X, DBSCAN_estimated_labels_1 , dims=2)
#       2 plt_tools.visualize_iris_ground_truth_2d()
#
# ~\OneDrive - University of Tasmania\World\Education\UTAS\AMSI summer\Code\Cluster_Validity\Jupyter Notebooks\Toolbox\plotting_functions.py in visualize_clusters(X, est_y, dims)
#      82     x_pca = pca.transform(X)
#      83
# ---> 84     est_y = np.choose(est_y, [1, 2, 0]).astype(np.float)
#      85     if dims == 3:
#      86         ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
#
# <__array_function__ internals> in choose(*args, **kwargs)
#
# ~\Anaconda3\envs\AMSI-2019\lib\site-packages\numpy\core\fromnumeric.py in choose(a, choices, out, mode)
#     430
#     431     """
# --> 432     return _wrapfunc(a, 'choose', choices, out=out, mode=mode)
#     433
#     434
#
# ~\Anaconda3\envs\AMSI-2019\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      59
#      60     try:
# ---> 61         return bound(*args, **kwds)
#      62     except TypeError:
#      63         # A TypeError occurs if the object does have such a method in its
#
# ValueError: invalid entry in choice array
